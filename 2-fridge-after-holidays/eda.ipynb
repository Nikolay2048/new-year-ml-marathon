# %%
import datetime
import pandas as pd

# %%
TRAIN_PATH = 'data/train_holodilnik.csv'
TEST_PATH = 'data/test_holodilnik.csv'
USERS_PATH = 'data/users.csv'
DISHES_PATH = 'data/dishes.csv'
OUT_PATH = 'data/submission_baseline.csv'
